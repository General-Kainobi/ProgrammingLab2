# %% [markdown]
# # 4. Rispondere alle domande
# Trasforma le seguenti richiesti in formule per estrarre infromazioni dal dataframe
# - Mostrami le vendite maggiori di 10
#
# - Mostrami i dati del 2018
#
# - Mostrami le vendite maggiori di 13 e l'anno è il 2018
#
# - Mostrami tutto TRANNE i casi in cui le vendite sono maggiori di 13 e l'anno è il 2018
#
# - Mostrami i dati dove le vendite divise per 3 sono maggiori di 3
#
# - Mostrami i dipendenti i cui nomi sono alfabeticamente dopo la J

# %%
import pandas as pd
import matplotlib as mplt
sales = pd.DataFrame(
    data={
        "employee": [
            "Katrina",
            "Guanyu",
            "Jan",
            "Roman",
            "Jacqueline",
            "Paola",
            "Esperanza",
            "Alaina",
            "Egweyn",
        ],
        "sales": [14, 17, 6, 12, 8, 3, 7, 15, 5],
        "year": [2018, 2019, 2020, 2018, 2020, 2019, 2019, 2020, 2020],
    }
)
sales

#sales[sales['sales'] > 10]
#sales[sales['year']==2018]
#sales[(sales['year'] == 2018) & (sales['sales'] > 13)]
#sales[(sales['year'] != 2018) & (sales['sales'] < 13)]
#sales[(sales['sales']/3>3)]
sales[sales['employee'].str.lower() > 'j']
# Out:
#      employee  sales  year
# 0     Katrina     14  2018
# 2         Jan      6  2020
# 3       Roman     12  2018
# 4  Jacqueline      8  2020
# 5       Paola      3  2019

# %% [markdown]
# # 5. Analisi di un dataset di video giochi
# 1. Quanti videogiochi sono stati pubblicati
# 2. Quali sono i generi più popolari? Mostralo con un bar plot
# 3. Plotta l'evoluzione del numero di giochi pubblicati nel tempo
# 4. Prova a riprodurre questo plot
# ![image.png](attachment:image.png)

# %%
# Import dei pacchetti
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Caricamento del dataset
url = 'https://zenodo.org/record/5898311/files/vgsales.csv'
df = pd.read_csv(url)
df.head()
#1
#df.count()
#2 
#if True:
    #genre_sales = df.groupby('Genre')['Global_Sales'].sum().sort_values(ascending=False)
    #plt.figure(figsize=(10, 6))
    #genre_sales.plot(kind="bar", color="skyblue", edgecolor="black")
    #plt.title("Total Global Sales by Genre", fontsize=16)
    #plt.xlabel("Genre", fontsize=14)
    #plt.ylabel("Global Sales (in millions)", fontsize=14)
    #plt.xticks(rotation=45, fontsize=12)
    #plt.tight_layout()
    #plt.show()
#3
""" if True:
    dfclean=df.dropna()
    genre_sales = dfclean['Year'].value_counts()
    genre_sales
    genre_sales = genre_sales.sort_index() #per avere un ordine cronologico giusto
    genre_sales.plot(kind='line', marker='o', linestyle='-', color='b')
    plt.title("Number of Games Published Over Time")
    plt.xlabel("Year")
    plt.ylabel("Number of Games")
    plt.grid(True)
    plt.show() """
#4
if True:
    genre_sales = df.groupby('Genre')[['EU_Sales','NA_Sales', 'JP_Sales', 'Other_Sales']].sum()
    genre_sales['Total_Sales'] = genre_sales.sum(axis=1)
    genre_sales = genre_sales.sort_values(by='Total_Sales', ascending=False).head(5)
    genre_sales = genre_sales.drop(columns=['Total_Sales'])
    plt.figure(figsize=(10, 6))
    genre_sales.plot(kind="bar",stacked=True, edgecolor="black")
    plt.title("Total Global Sales by Genre", fontsize=16)
    plt.xlabel("Genre", fontsize=14)
    plt.ylabel("Global Sales (in millions)", fontsize=14)
    plt.xticks(rotation=45, fontsize=12)
    plt.tight_layout()
    plt.show()
#df.head()
